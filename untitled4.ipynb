# %% [markdown]
# <a href="https://colab.research.google.com/github/Baryga123/lab/blob/main/untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install CoolProp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 42.4 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import CoolProp.CoolProp as ct
import matplotlib.pyplot as plt
t=np.linspace(73.15,393.15,100)
Fluid_name="CH4"
#10-100 gradus
p=101300
d=ct.PropsSI('D','P',p,'T',t,Fluid_name)
plt.plot(t,d,'r')
plt.grid()
plt.show()
print(d)
# Out:
# [         inf          inf          inf          inf          inf
#           inf 449.0662768  444.71286521 440.30179141 435.8272991
#  431.28320195 426.66273403   1.81103542   1.75460203   1.70195412
#    1.65266606   1.60638656   1.56281901   1.5217093    1.48283746
#    1.44601147   1.41106259   1.3778416    1.34621587   1.31606693
#    1.28728851   1.25978489   1.23346957   1.20826408   1.18409704
#    1.16090335   1.13862344   1.11720272   1.09659099   1.07674205
#    1.05761323   1.03916511   1.02136115   1.00416747   0.98755258
#    0.97148716   0.9559439    0.94089729   0.9263235    0.91220024
#    0.8985066    0.88522299   0.872331     0.85981333   0.8476537
#    0.83583678   0.82434809   0.813174     0.80230161   0.79171873
#    0.78141384   0.771376     0.76159489   0.75206067   0.74276403
#    0.73369612   0.72484854   0.71621327   0.70778272   0.69954963
#    0.6915071    0.68364852   0.67596763   0.66845842   0.66111515
# ...
